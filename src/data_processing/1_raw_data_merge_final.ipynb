# %% [markdown]
# #### DLS Project - Recommendation System using GNN
# 1. Data Processing Script
# 2. Read the raw datasets
# 3. Merge meta data and review data files for modeling

# %%
import os
import pandas as pd
import gzip
import json
import numpy as np

# %% [markdown]
# **Reading Meta Data File**

# %%
'''Step1 : Load and clean meta Data file'''
#os.chdir(r'/N/u/abbajpai/Carbonate/Documents/data/Raw data')
os.chdir(r'/N/project/APRS/') # Change path to data
metaRawData = []
with gzip.open('meta_Books.json.gz') as f:
    for l in f:
        metaRawData.append(json.loads(l.strip()))

# %%
# Convert list into pandas dataframe and check for duplicates
metaData = pd.DataFrame.from_dict(metaRawData)
metaData = metaData.drop_duplicates(subset='asin', keep='first')
metaData = metaData.dropna(subset=['category']) # no nulls
metaData = metaData[metaData!='[ ]']

# %%
# Extracting last value in category field
metaData['categoryLast'] = metaData['category'].astype(str).str.rsplit(',').str[-1]
metaData['categoryLast'] = metaData['categoryLast'].replace('\]', '', regex=True) 
metaData['categoryLast'] = metaData['categoryLast'].replace('\'', '', regex=True)

# %%
metaData['categoryLast']=metaData['categoryLast'].replace('\[', '',regex=True)

# %%
# Save file
metaDataFilter=metaData
metaDataFilter.to_pickle('1_metaData.pkl') # for future use

# %% [markdown]
# ##### Reading Review Data File

# %%
'''Step2 : Load and clean Review Data file and merge with meta data'''

reviewRawData = []
i=0
with gzip.open('Books_5.json.gz') as f:
    for l in f:
        i+=1
        ly=""
        ly=json.loads(l.strip())
        if ly['reviewTime'].endswith((', 2016',', 2017',', 2018')):
            reviewRawData.append(ly)
        if (i==40000000): #  limit to avoid memory issue
            break
# total length of list, this number equals total number of products
print(len(reviewRawData))

# convert list into pandas dataframe and drop nulls
reviewData = pd.DataFrame.from_dict(reviewRawData)

reviewData= reviewData.dropna(subset=['asin'])
mergedData= pd.merge(reviewData,metaDataFilter, how='inner', on='asin')

print(len(mergedData))
mergedData.to_pickle('2_mergedData_final.pkl')
# Out:
# 9824156
# 9823656

# %%
# Sample check
mergedData[0:100]
# Out:
#     overall  verified   reviewTime      reviewerID        asin  \
# 0       5.0      True  06 20, 2016   AVP0HXC9FG790  0001713353
# 1       5.0      True  01 24, 2016  A324TTUBKTN73A  0001713353
# 2       5.0      True   10 6, 2017  A13WB96L3AKB6U  0001713353
# 3       5.0     False   06 2, 2017  A26ZH70F6R1RXI  0001713353
# 4       5.0      True   05 8, 2017  A1EE8B7JW9Q4LC  0001713353
# ..      ...       ...          ...             ...         ...
# 95      5.0      True  07 17, 2017  A2L4BBNT6DXHWM  0001384198
# 96      3.0      True  06 20, 2017   AGIEJEH5K1WMT  0001384198
# 97      5.0      True  06 16, 2017  A3EY4VI8K6JLUU  0001384198
# 98      5.0     False  06 13, 2017  A34TPFLDV1ZG70  0001384198
# 99      5.0      True  06 10, 2017  A2ANJLL8HNNO1D  0001384198
#
#           reviewerName                                         reviewText  \
# 0      Amazon Customer                                 The kids loved it!
# 1         Tekla Borner  My students (3 & 4 year olds) loved this book!...
# 2            C. Morgan  This is a family favorite.\nIt has been one of...
# 3           Kindle_mom                                     Very fun book!
# 4   Michelle A. Harris  The Book is in pristine condition.  I had no i...
# ..                 ...                                                ...
# 95              L barb                                       BEST classic
# 96                Sara  I didn't realize this is a mini booklet , when...
# 97                tres  What can one say bad about the little engine t...
# 98               Sandi                             Perfect for our needs.
# 99   Richard A. Massey  Sadly someone thought it was a good idea to cu...
#
#                                    summary  unixReviewTime  \
# 0                               Five Stars      1466380800
# 1                               Five Stars      1453593600
# 2                      ALL TIME FAVORITE!!      1507248000
# 3                                Loved it!      1496361600
# 4           Fabulous! Better than Expected      1494201600
# ..                                     ...             ...
# 95                              Five Stars      1500249600
# 96                          Interesting !!      1497916800
# 97                   He could, you should!      1497571200
# 98                              Five Stars      1497312000
# 99  The original art and unabridged story!      1497052800
#
#                         style  ...                  rank  \
# 0                         NaN  ...  1,461,315 in Books (
# 1   {'Format:': ' Paperback'}  ...  1,461,315 in Books (
# 2   {'Format:': ' Hardcover'}  ...  1,461,315 in Books (
# 3                         NaN  ...  1,461,315 in Books (
# 4                         NaN  ...  1,461,315 in Books (
# ..                        ...  ...                   ...
# 95  {'Format:': ' Hardcover'}  ...  3,286,778 in Books (
# 96  {'Format:': ' Hardcover'}  ...  3,286,778 in Books (
# 97  {'Format:': ' Hardcover'}  ...  3,286,778 in Books (
# 98  {'Format:': ' Hardcover'}  ...  3,286,778 in Books (
# 99  {'Format:': ' Hardcover'}  ...  3,286,778 in Books (
#
#                                             also_view main_cat similar_item  \
# 0   [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# 1   [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# 2   [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# 3   [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# 4   [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# ..                                                ...      ...          ...
# 95               [0448405202, B000OKY9X0, 0399244670]    Books
# 96               [0448405202, B000OKY9X0, 0399244670]    Books
# 97               [0448405202, B000OKY9X0, 0399244670]    Books
# 98               [0448405202, B000OKY9X0, 0399244670]    Books
# 99               [0448405202, B000OKY9X0, 0399244670]    Books
#
#    date   price imageURL imageURLHighRes details           categoryLast
# 0        $12.33       []              []     NaN   Literature & Fiction
# 1        $12.33       []              []     NaN   Literature & Fiction
# 2        $12.33       []              []     NaN   Literature & Fiction
# 3        $12.33       []              []     NaN   Literature & Fiction
# 4        $12.33       []              []     NaN   Literature & Fiction
# ..  ...     ...      ...             ...     ...                    ...
# 95       $16.04       []              []     NaN   Literature & Fiction
# 96       $16.04       []              []     NaN   Literature & Fiction
# 97       $16.04       []              []     NaN   Literature & Fiction
# 98       $16.04       []              []     NaN   Literature & Fiction
# 99       $16.04       []              []     NaN   Literature & Fiction
#
# [100 rows x 31 columns]

# %%
# Split into year for initial model building
data_16=mergedData.loc[mergedData['reviewTime'].str.contains("2016",case=False)]
data_17=mergedData.loc[mergedData['reviewTime'].str.contains("2017",case=False)]
data_18=mergedData.loc[mergedData['reviewTime'].str.contains("2018",case=False)]
print(len(data_16),len(data_17),len(data_18))
# Out:
# 4494142 3933994 1395520

# %% [markdown]
# ##### Data exploration

# %%
# Book Avg. Rating
mergedData1=mergedData
mergedData1['finalreview']=mergedData1.groupby(['asin'])['overall'].transform('mean')
mergedData1['finalreview']=np.round_(mergedData1.finalreview,decimals=1)
finalData=mergedData1[["asin","reviewerID","finalreview","reviewTime"]]
print(len(finalData))
mergedData1.to_pickle('total_data_avg.pkl')
mergedData1[1:10]
# Out:
# 9823656
#    overall  verified   reviewTime      reviewerID        asin  \
# 1      5.0      True  01 24, 2016  A324TTUBKTN73A  0001713353
# 2      5.0      True   10 6, 2017  A13WB96L3AKB6U  0001713353
# 3      5.0     False   06 2, 2017  A26ZH70F6R1RXI  0001713353
# 4      5.0      True   05 8, 2017  A1EE8B7JW9Q4LC  0001713353
# 5      5.0      True  12 10, 2016   ARBC5VQWIPRMR  0001713353
# 6      5.0      True   10 6, 2016   A2CVLIZ9ELU88  0001061240
# 7      5.0     False  09 16, 2016  A2LGACKSC0MALY  0001061240
# 8      5.0     False   01 7, 2016    A6EQG0P75KHJ  0001061240
# 9      5.0      True  04 15, 2018   A37NYSAZ4SSO1  0001061240
#
#          reviewerName                                         reviewText  \
# 1        Tekla Borner  My students (3 & 4 year olds) loved this book!...
# 2           C. Morgan  This is a family favorite.\nIt has been one of...
# 3          Kindle_mom                                     Very fun book!
# 4  Michelle A. Harris  The Book is in pristine condition.  I had no i...
# 5      Debbie Lampert  This book is eternal. I read it to my children...
# 6              A.M.H.  I had this book as a child and loved it. The c...
# 7         Sharon Katz  My aunt bought me this book in 1962 - I was te...
# 8      Bookworm 93103  I agree with another reviewer, that every home...
# 9     Amazon Customer  My mother gave me my copy of this when I was o...
#
#                                              summary  unixReviewTime  \
# 1                                         Five Stars      1453593600
# 2                                ALL TIME FAVORITE!!      1507248000
# 3                                          Loved it!      1496361600
# 4                     Fabulous! Better than Expected      1494201600
# 5                                   An Eternal Story      1481328000
# 6  A wonderful poetry collection with superior co...      1475712000
# 7      The Best Poetry Books For Children And Adults      1473984000
# 8  Enchanting poetry and illustrations, a true cl...      1452124800
# 9                  Sure to become a family heirloom!      1523750400
#
#                        style  ...  \
# 1  {'Format:': ' Paperback'}  ...
# 2  {'Format:': ' Hardcover'}  ...
# 3                        NaN  ...
# 4                        NaN  ...
# 5  {'Format:': ' Hardcover'}  ...
# 6  {'Format:': ' Hardcover'}  ...
# 7  {'Format:': ' Hardcover'}  ...
# 8                        NaN  ...
# 9  {'Format:': ' Hardcover'}  ...
#
#                                            also_view main_cat similar_item  \
# 1  [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# 2  [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# 3  [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# 4  [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# 5  [0394800230, B01K8ZBL54, 0140564349, B000X6VEW...    Books
# 6  [B001HDIKYW, B000LTQDP6, 0307168514, 039485010...    Books
# 7  [B001HDIKYW, B000LTQDP6, 0307168514, 039485010...    Books
# 8  [B001HDIKYW, B000LTQDP6, 0307168514, 039485010...    Books
# 9  [B001HDIKYW, B000LTQDP6, 0307168514, 039485010...    Books
#
#   date   price imageURL imageURLHighRes details           categoryLast  \
# 1       $12.33       []              []     NaN   Literature & Fiction
# 2       $12.33       []              []     NaN   Literature & Fiction
# 3       $12.33       []              []     NaN   Literature & Fiction
# 4       $12.33       []              []     NaN   Literature & Fiction
# 5       $12.33       []              []     NaN   Literature & Fiction
# 6       $23.98       []              []     NaN   Literature & Fiction
# 7       $23.98       []              []     NaN   Literature & Fiction
# 8       $23.98       []              []     NaN   Literature & Fiction
# 9       $23.98       []              []     NaN   Literature & Fiction
#
#   finalreview
# 1         5.0
# 2         5.0
# 3         5.0
# 4         5.0
# 5         5.0
# 6         5.0
# 7         5.0
# 8         5.0
# 9         5.0
#
# [9 rows x 32 columns]
