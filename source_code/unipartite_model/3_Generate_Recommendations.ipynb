# %% [markdown]
# #### DLS Project - Recommendation System using GNN
# 1. Unipartite Model
# 2. Script to load the model output
# 3. Find sample cases for manual review of recommendations made by the model
# 4. Input Files availabe at - https://indiana-my.sharepoint.com/:f:/g/personal/abbajpai_iu_edu/EhlGzk26Td9EvsykPVD6kcABji4dRHR2fvRf6E8d1FdlKA?e=fusaup

# %%
import pandas as pd
import numpy as np
import os
PATH = '/N/project/APRS/model_user_results'

# %% [markdown]
# ##### Loading the saved embeddings and dataframe

# %%
# load the dataframe
data_df_3_sample = pd.read_pickle(os.path.join(PATH, 'data_df_3_sample.pkl'))

# %%
# load the embeddings
h = pd.read_csv(os.path.join(PATH,'embedding_vector_user.csv'))

# %%
# load the node list
nodes_list = pd.read_pickle(os.path.join(PATH,'node_list.pkl'))
nodes_list = nodes_list[0].tolist()

# %% [markdown]
# ##### Generating results

# %%
# Step 1: Select any category
data_df_3_sample.categoryLast.unique()
# Out:
# array([' Thrillers & Suspense', ' Americas',
#        ' Research &amp; Publishing Guides', ' United States',
#        ' Thrillers &amp; Suspense', ' Thriller & Suspense',
#        ' Genre Fiction', ' British & Irish', ' British &amp; Irish',
#        ' Action &amp; Adventure', ' Fantasy', ' Science Fiction',
#        ' Crafts & Hobbies', ' Historical', ' Contemporary',
#        ' Arts &amp; Literature', ' Mystery', ' Literature &amp; Fiction',
#        ' Politics &amp; Government', ' Military', '',
#        ' Science Fiction &amp; Fantasy', ' Time Travel',
#        ' Holidays &amp; Celebrations', ' Paranormal', ' Graphic Novels',
#        ' Short Stories &amp; Anthologies',
#        ' Growing Up &amp; Facts of Life', ' "Womens Fiction"',
#        ' Humor & Satire', ' Bible Study &amp; Reference',
#        ' Literature & Fiction', ' Religion &amp; Spirituality',
#        ' Science Fiction & Fantasy', ' Photography &amp; Video', ' Humor',
#        ' Professionals & Academics', ' "Childrens Books"',
#        ' Pets &amp; Animal Care', ' Crafts &amp; Hobbies', ' Music',
#        ' Humanities', ' New Adult &amp; College', ' Romantic Comedy',
#        ' Literary', ' Clean & Wholesome', ' Humor &amp; Satire',
#        ' Erotica', ' Anthologies', ' Crime',
#        ' Growing Up & Facts of Life', ' Early Learning', ' Biographies',
#        ' Home Improvement &amp; Design', ' Motivational',
#        ' Romantic Suspense', ' Action & Adventure', ' Animals', ' Baking',
#        ' Kitchen Appliances', ' Cooking by Ingredient',
#        ' Exercise & Fitness', ' Regional & International',
#        ' Survival &amp; Emergency Preparedness', ' Social Sciences',
#        ' Politics & Government', ' History &amp; Criticism',
#        ' World Literature', ' Europe', ' Ancient Civilizations',
#        ' Poetry', ' Arts & Literature', ' World',
#        ' Language &amp; Grammar', ' Death & Grief', ' Engineering',
#        ' Religious Studies', ' Christian Living', ' Relationships',
#        ' Individual Sports', ' Leaders &amp; Notable People', ' Western',
#        ' LGBT', ' Family Relationships', ' Alternative Medicine',
#        ' Short Stories & Anthologies', ' Mythology &amp; Folk Tales',
#        ' Architecture', ' Drawing', ' Classics', ' Dramas &amp; Plays',
#        ' Music &amp; Photography', ' Education &amp; Reference',
#        ' Publishers', ' History & Criticism', ' Graphic Design',
#        ' Photography & Video', ' Dramas & Plays', ' Buddhism',
#        ' Medicine &amp; Health Sciences', ' Schools &amp; Teaching',
#        ' Marketing &amp; Sales', ' Geography & Cultures',
#        ' Crafts &amp; Games', ' Mental Health', ' Economics',
#        ' Self-Help', ' Gothic', ' Professionals &amp; Academics',
#        ' True Crime', ' New Age & Spirituality', ' New Adult & College',
#        ' Nature &amp; How It Works', ' Astronomy &amp; Space Science',
#        ' Romance', ' Hunting &amp; Fishing', ' Manga', ' Medicine',
#        ' Management &amp; Leadership', ' Specific Groups',
#        ' Gardening &amp; Landscape Design', ' Automotive',
#        ' Diets &amp; Weight Loss', ' Thriller &amp; Suspense',
#        ' Middle East', ' Christian Books & Bibles', ' Anthropology',
#        ' Earth Sciences', ' Memory Improvement', ' Investing',
#        ' Food &amp; Wine', ' Hiking & Camping', ' Performing Arts',
#        ' Diseases & Physical Ailments', ' Vegetarian &amp; Vegan',
#        ' Beverages &amp; Wine', ' Special Diet', ' Cooking Methods',
#        ' Cooking Education & Reference', ' Biographies & Memoirs',
#        ' Australia & South Pacific', ' Transportation', ' Multicultural',
#        ' Comics &amp; Graphic Novels', ' Death &amp; Grief',
#        ' Leaders & Notable People', ' Psychology &amp; Counseling',
#        ' Processes &amp; Infrastructure', ' Movies', ' Fashion',
#        ' Psychology & Counseling', ' Philosophy',
#        ' Mysteries &amp; Thrillers', ' Mythology & Folk Tales',
#        ' Catalogs &amp; Exhibitions', ' Schools & Teaching',
#        ' Mathematics', ' Occult &amp; Paranormal', ' Real Estate',
#        ' Professional', ' Management & Leadership', ' Happiness',
#        ' Memoirs', ' Catholicism', ' Crafts & Games',
#        ' Exercise &amp; Fitness', ' Bisexual &amp; Transgender Books',
#        ' Games & Strategy Guides', ' Radio', ' Historical Fiction',
#        ' Holidays', ' Diseases &amp; Physical Ailments', ' Religions',
#        ' Asia', ' Ethnic &amp; National', ' Pop Culture', ' Other Media',
#        ' Christian Books &amp; Bibles',
#        ' Christian Denominations & Sects', ' Geography &amp; Cultures',
#        ' Industries', ' Pets & Animal Care', ' Language & Grammar',
#        ' Science &amp; Mathematics', ' Biological Sciences',
#        ' Home Improvement & Design', ' Television', ' Theology',
#        ' History', ' Computers &amp; Technology', ' Individual Artists',
#        ' Small Business & Entrepreneurship', ' Business Culture',
#        ' Folk Tales &amp; Myths', ' Personal Transformation',
#        ' Operating Systems', ' Encyclopedias & Subject Guides',
#        ' Bible Study & Reference', ' Paranormal & Urban', ' Canada',
#        ' Research & Publishing Guides', ' Nature &amp; Ecology',
#        ' Specialty Travel', ' Africa', ' Mountaineering',
#        ' Regional U.S.', ' Creativity', ' Bibles', ' Adoption',
#        ' Constitutional Law', ' Education & Reference', ' Psychology',
#        ' Puzzles &amp; Games', ' Occult & Paranormal', ' Sports',
#        ' Clean &amp; Wholesome', ' New Age &amp; Spirituality',
#        ' Practices & Sacred Texts', ' Mysteries & Thrillers', ' Skills',
#        ' Success', ' Fitness &amp; Dieting', ' Painting',
#        ' Small Business &amp; Entrepreneurship', ' Outdoor Cooking',
#        ' Programming', ' Programming Languages',
#        ' Worship &amp; Devotion', ' Biographies &amp; Memoirs',
#        ' Parenting &amp; Relationships', ' Personal Finance',
#        ' Authorship', ' Mystery & Thrillers', ' Fitness & Dieting',
#        ' Agricultural Sciences', ' Rules &amp; Procedures',
#        ' Antiques & Collectibles', ' Administrative Law',
#        ' Folk Tales & Myths', ' Nature & How It Works',
#        ' Holidays & Celebrations', ' Sports &amp; Outdoors',
#        ' Mystery &amp; Thrillers', ' Family',
#        ' Medicine & Health Sciences', ' Marketing & Sales',
#        ' Used &amp; Rental Textbooks', ' Catalogs & Exhibitions',
#        ' Trains & Things That Go', ' Parenting', ' Family Saga',
#        ' Hunting & Fishing', ' Sociology',
#        ' Networking & Cloud Computing', ' Mid-Life',
#        ' Administration &amp; Medicine Economics',
#        ' Main Courses &amp; Side Dishes', ' Sexual Health',
#        ' Essays & Correspondence', ' Mystery & Thriller',
#        ' Music & Photography', ' Hinduism', ' Vegetarian & Vegan',
#        ' Decorative Arts &amp; Design', ' Judaism',
#        ' Practices &amp; Sacred Texts', ' Travelers &amp; Explorers',
#        ' Water Sports', ' Certification',
#        ' Cooking Education &amp; Reference', ' Other Team Sports',
#        ' Sports Health &amp; Safety', ' Addiction &amp; Recovery',
#        ' College &amp; High School', ' Education', ' South America',
#        ' Pharmacology', ' "Womens Health"', ' Teen &amp; Young Adult',
#        ' Trains &amp; Things That Go', ' Gaming', ' Quick & Easy',
#        ' Computer Science', ' Regional &amp; International', ' Finance',
#        ' Job Hunting &amp; Careers', ' Biography &amp; History',
#        ' Networking &amp; Cloud Computing', ' Astronomy & Space Science',
#        ' Arts &amp; Photography', ' Time Management',
#        ' and code snippets illustrating key technical concepts.',
#        ' Web Development &amp; Design', ' Diets & Weight Loss',
#        ' Atlases &amp; Maps', ' Churches & Church Leadership',
#        ' "Childrens Health"', ' Sex', ' Atheism', ' Stress Management',
#        ' Education &amp; Teaching', ' Inner Child',
#        ' Antiques &amp; Collectibles', ' Essays &amp; Correspondence',
#        ' Chemistry', ' Foreign Language Study &amp; Reference',
#        ' Actors & Entertainers', ' Main Courses & Side Dishes',
#        ' Regency', ' Police Procedurals', ' Gardening & Landscape Design',
#        ' International', ' Studying &amp; Workbooks',
#        ' Graphics &amp; Design', ' Job Hunting & Careers',
#        ' Churches &amp; Church Leadership', ' Worship & Devotion',
#        ' Beverages & Wine', ' Hiking &amp; Camping',
#        ' Historical Study & Educational Resources', ' Evolution',
#        ' Miscellaneous', ' Ministry &amp; Evangelism',
#        ' Allied Health Professions', ' Family Law', ' "Childrens"',
#        ' "Womens Studies"', ' Software', ' Mysteries &amp; Detectives',
#        ' Special Needs', ' Ethnic & National',
#        ' Dictionaries &amp; Thesauruses', ' History &amp; Philosophy',
#        ' Billionaires', ' Essays &amp; Commentary',
#        ' History & Philosophy', ' &amp; Style', ' Business & Finance',
#        ' Processes & Infrastructure', ' Nutrition',
#        ' Entertaining &amp; Holidays', ' Travel', ' Addiction & Recovery',
#        ' Caribbean', ' Communication & Journalism', ' Nature & Ecology',
#        ' Victorian', ' </span>', ' Genealogy', ' Field Guides',
#        ' Human Resources', ' Vampires', ' & Style',
#        ' Travelers & Explorers', ' Comics & Graphic Novels', ' Horror',
#        ' Used & Rental Textbooks', ' Journal Writing', ' Comic Strips',
#        ' Kidnapping', ' Protestantism', ' Accounting',
#        ' Internet &amp; Social Media', ' Reference', ' Suspense',
#        ' Aging', ' Graduate School', ' Hobbies &amp; Games',
#        ' Australia &amp; South Pacific', ' Business',
#        ' Tablets &amp; E-Readers', ' Tablets & E-Readers', ' Romantic',
#        ' Atlases & Maps', ' Ministry & Evangelism',
#        ' Christian Denominations &amp; Sects',
#        ' Games &amp; Strategy Guides', ' Social Issues', ' Law',
#        ' Ancient &amp; Medieval Literature', ' Environment', ' Nursing',
#        ' Golf', ' Encyclopedias &amp; Subject Guides', ' Etiquette',
#        ' Hardware &amp; DIY', ' Quick &amp; Easy', ' Islam',
#        ' Canning &amp; Preserving', ' Physics', ' Behavioral Sciences',
#        ' Web Development & Design', ' Teen & Young Adult', ' Coaching',
#        ' Internet & Social Media', ' Food & Wine',
#        ' Science & Mathematics', ' Test Prep & Study Guides',
#        ' Legal Theory &amp; Systems', ' Criminal Law',
#        ' Religion & Spirituality', ' Spiritual', ' Scottish', ' Hypnosis',
#        ' Business &amp; Finance', ' Adventure', ' Astronomy', ' Arts',
#        ' Travel Writing', ' Decorative Arts & Design', ' Quotations',
#        ' Puzzles & Games', ' Garden &amp; Home', ' Insurance',
#        ' Higher & Continuing Education', ' Australia &amp; Oceania',
#        ' Weddings', ' Women &amp; Business', ' Extreme Sports',
#        ' Card Games', ' Bisexual & Transgender Books', ' Racket Sports',
#        ' Medical Books', ' Foreign Language Study & Reference',
#        ' Databases & Big Data', ' Lodging & Transportation',
#        ' Business &amp; Money', ' Essays', ' Training', ' Calendars',
#        ' Trees', ' Hardware & DIY', ' Winter Sports',
#        ' Entertaining & Holidays', ' Aging Parents',
#        ' Historical Study &amp; Educational Resources',
#        ' Consumer Guides', ' Personal Health', ' Anger Management',
#        ' Humorous', ' Biography & History', ' Technology',
#        ' Communication &amp; Journalism', ' Databases &amp; Big Data',
#        ' Higher &amp; Continuing Education', ' Emotions', ' Martial Arts',
#        ' Mysteries & Detectives', ' Canning & Preserving',
#        ' Safety &amp; First Aid', ' Occult', ' Women & Business',
#        ' Baseball', ' College & High School', ' Political',
#        ' "Childrens Cookbooks"', ' Business & Money', ' Self-Esteem',
#        ' Dictionaries & Thesauruses', ' Tax Law', ' Space Opera',
#        ' Psychological', ' Probability &amp; Statistics',
#        ' Security &amp; Encryption', ' Law Practice', ' Photography',
#        ' Sports & Outdoors', ' Entrepreneurship', ' Russia',
#        ' Rules & Procedures', ' Humor & Entertainment',
#        ' Intellectual Property', ' Event Planning',
#        ' Football (American)', ' Interpersonal Relations',
#        ' Eating Disorders', ' Dark Humor',
#        ' Other Eastern Religions &amp; Sacred Texts', ' New Experiences',
#        ' Piano', ' How To Create Comics &amp; Manga', ' Specialties',
#        ' Sustainable Living', ' Women Sleuths', ' Computers & Technology',
#        ' Supernatural', ' Psychics', ' African Americans', ' Marriage',
#        ' Ghosts', ' State &amp; Local', ' Family Life', ' Basketball',
#        ' Panama', ' Thrillers', ' New England', ' Studying & Workbooks',
#        ' Humor &amp; Entertainment', ' Survival & Emergency Preparedness',
#        ' Desserts', ' Leadership',
#        ' Other Eastern Religions & Sacred Texts',
#        ' Test Prep &amp; Study Guides', ' New Age', ' Blank Sheet Music',
#        ' Business Technology', ' Wrestling', ' Paranormal &amp; Urban',
#        ' Models', ' Dating & Sex', ' Diet &amp; Health',
#        ' Quilts &amp; Quilting', ' Legal Education',
#        ' Communication &amp; Social Skills', ' Parenting & Relationships',
#        ' Neuro-Linguistic Programming', ' Holocaust',
#        ' Health &amp; Medical Law', ' International Mystery & Crime',
#        ' Video &amp; Photography', ' Espionage', ' Sea Stories',
#        ' Arts & Photography', ' Hard Science Fiction',
#        ' Xbox streaming etc.', ' Archaeology', ' Science &amp; Math',
#        ' Inspirational', ' "Mens Health"',
#        ' Ancient & Medieval Literature', ' Epic', ' State & Local',
#        ' Family Activities', ' Pentecostal & Charismatic',
#        ' Lodging &amp; Transportation', ' Legal Theory & Systems',
#        ' Private Investigators', ' Trivia &amp; Fun Facts', ' England',
#        ' Collections & Anthologies', ' Dreams', ' Conflict Management',
#        ' Conservatism & Liberalism', ' Abuse',
#        ' Reference &amp; Collections', ' Coming of Age',
#        ' Anxieties &amp; Phobias', ' Trivia & Fun Facts',
#        ' Anxieties & Phobias', ' Reference & Collections', ' Research',
#        ' Torts', ' Cycling', ' Agnosticism', ' Workbooks',
#        ' Politics &amp; Social Sciences', ' Australia & Oceania',
#        ' Excursion Guides', ' Actors &amp; Entertainers',
#        ' Celebrities & TV Shows', ' Taxation', ' Catalogs & Directories',
#        ' Papercrafts', ' Day Care &amp; Child Care', ' Basic Sciences',
#        ' Central America', ' Administration', ' Polar Regions',
#        ' Study & Teaching', ' History & Culture', ' Sculpture',
#        ' Science & Math', ' Politics & Social Sciences', ' Soccer',
#        ' Foreign Language', ' Veterinary Medicine',
#        ' Almanacs & Yearbooks', ' Video & Photography',
#        ' Fantasy & Science Fiction', ' Safety & First Aid',
#        ' Communication & Social Skills', ' Rodeos', ' Natural Foods',
#        ' Catalogs &amp; Directories', ' Graphics & Design',
#        ' Emotions &amp; Feelings', ' Hockey', ' Regional Canada',
#        ' Humor &amp; Comics', ' Acting & Auditioning', ' Book Design',
#        ' Art', ' History &amp; Culture', ' Self Esteem & Reliance',
#        ' Violins', ' Projects', ' Mexico', ' General', ' Business of Art',
#        ' Study &amp; Teaching', ' Cultural Heritage',
#        ' Instruments &amp; Measurement',
#        ' "A keep-motivated personal progress chart in the back."',
#        ' Sports Health & Safety', ' American Civil War',
#        ' Ethics &amp; Professional Responsibility', ' Domestic Life',
#        ' Outdoor Recreation', ' School', ' Arithmetic',
#        ' Operation Desert Storm', ' Business & Professional',
#        ' 20th Century', ' Biology', ' Humor & Comics',
#        ' How To Create Comics & Manga', ' Remote Sensing &amp; GIS',
#        ' Pasta &amp; Noodles', ' Mystery & Suspense',
#        ' Orphans & Foster Homes', ' Legal Self-Help', ' Dogs',
#        ' Activity Books', ' Almanacs &amp; Yearbooks', ' Divination',
#        ' Day Care & Child Care', ' Landscapes',
#        ' English as a Second Language', ' Hobbies &amp; Home',
#        ' Terrorism', ' Cozy', ' Hobbies & Home', ' War',
#        ' Popular Culture', ' Estate Planning', ' Applique',
#        ' teaspoon chili powder', ' Other Diets', ' Wildlife',
#        ' Family Health', ' Mountain Climbing', ' Murder & Mayhem',
#        ' Slow Cookers', ' Security & Encryption', ' Coloring Books',
#        ' Screenplays', ' Jewelry', ' Comic Books', ' Cats',
#        ' Dictionaries &amp; Terminology',
#        ' Foreign &amp; International Law', ' Pictorial', ' Mushrooms',
#        ' Professional Cooking', ' Women', ' Kosher', ' Legal History',
#        ' Letters', ' Administration & Medicine Economics',
#        ' Coffee & Tea', ' Education & Teaching', ' Diseases',
#        ' Dentistry', ' Scrabble', ' Tarot', ' Mountain', ' Guides',
#        ' Mid Atlantic', ' Travel & Scenery', ' Study Guides',
#        ' Instructional', ' Hobbies & Games', ' Instruments & Measurement',
#        ' Made in USA', ' Travel &amp; Scenery', ' Songwriting',
#        ' Allergies', ' Language Arts', ' Maps', ' Canadian', ' Cakes',
#        ' Fertility', ' Cooking', ' London', ' Children &amp; Teens',
#        ' Garden & Home', ' Puzzles', ' Pathfinder',
#        ' Fashion &amp; Jewelry', ' Discrimination & Racism',
#        ' Repair & Performance', ' Ethics & Professional Responsibility',
#        ' Arctic &amp; Antarctica', ' Instruction Methods',
#        ' Use of Color', ' Science Fiction &amp; Dystopian',
#        ' Vaccinations', ' Reading &amp; Phonics', ' Essays & Commentary',
#        ' Religious', ' Nature', ' Birdwatching', ' Organized Crime',
#        ' Atlases & Gazetteers', ' Handwriting Analysis', ' Medieval',
#        ' Celebrities &amp; TV Shows', ' Atlases &amp; Gazetteers',
#        ' Board Games', ' Air & Space Science', ' Camping', ' Guitar',
#        ' Jacket: hardcover', ' Civil War', ' Plants &amp; Animals',
#        ' Evenly or unevenly spaced time series.', ' Hunting',
#        ' Cast Iron', ' Weaponsmithing'], dtype=object)

# %%
# Step 2: Select sample examples >> Beaware of space in the category
sample_users = data_df_3_sample[data_df_3_sample["categoryLast"].isin([' Science Fiction'])]

# %%
# Step 3: Pick an example from this table
sample_users.head()
# Out:
#     overall  verified   reviewTime      reviewerID        asin reviewerName  \
# 14      3.0     False  12 27, 2017  A21FZK6X6CVS2Q  0999214756      JMScott
# 15      5.0     False   12 1, 2017  A21FZK6X6CVS2Q  1502544296      JMScott
# 17      5.0     False   06 5, 2016  A21FZK6X6CVS2Q  1519008570      JMScott
# 20      5.0     False  01 12, 2018  A21FZK6X6CVS2Q  0989931994      JMScott
# 21      4.0     False  10 20, 2016  A21FZK6X6CVS2Q  1539316653      JMScott
#
#                                            reviewText  \
# 14  The majority of Mr. McGinnis' books revolve ar...
# 15  Commander Creed creates a new type of human or...
# 17  Read the whole trilogy from start to finish......
# 20  When Earth receives a psychic signal in the 19...
# 21  A former Marine stumbles upon a group of alien...
#
#                                               summary  unixReviewTime  \
# 14                        Young Adult Science Fiction      1514332800
# 15   The final confrontation with the Purple Emperors      1512086400
# 17  Ended the Trilogy with all the questions answe...      1465084800
# 20  An alien signal warning Earth of a coming inva...      1515715200
# 21      An ancient alien menace rises awakes on Earth      1476921600
#
#                              style  ... imageURL imageURLHighRes details  \
# 14  {'Format:': ' Kindle Edition'}  ...       []              []     NaN
# 15  {'Format:': ' Kindle Edition'}  ...       []              []     NaN
# 17  {'Format:': ' Kindle Edition'}  ...       []              []     NaN
# 20  {'Format:': ' Kindle Edition'}  ...       []              []     NaN
# 21  {'Format:': ' Kindle Edition'}  ...       []              []     NaN
#
#         categoryLast asin_right buy_frequency user_id_idx item_id_idx  \
# 14   Science Fiction        143             1      129105      147463
# 15   Science Fiction        143             1      129105      194416
# 17   Science Fiction        143             1      129105      206478
# 20   Science Fiction        143             1      129105      139083
# 21   Science Fiction        143             1      129105      220628
#
#    price_right price_category
# 14       21.99              0
# 15       21.99              0
# 17       21.99              0
# 20       21.99              0
# 21       21.99              0
#
# [5 rows x 37 columns]

# %%
# Step 4: Load a reviewer name
reviwerID_val = 'A1PZU88ONVYUHB' # Example >>>>>  CHANGE THIS <<<<<<<<<<<< A2TS60D6XB4KBY
index = [i for i, x in enumerate(nodes_list) if reviwerID_val==x]
print(f'reviewerID index in graph {index}')
# Out:
# reviewerID index in graph [12]

# %%
# review the selected reviewer's book id
data_df_3_sample[data_df_3_sample.reviewerID == 'A2ASNCPAZWNTF0']
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      4.0      True   05 7, 2017  A2ASNCPAZWNTF0  1503936805
# 1      5.0      True  07 12, 2017  A2ASNCPAZWNTF0  1517153158
#
#       reviewerName                                         reviewText  \
# 0  Amazon Customer  Good read but clearly fiction. Moves fast, har...
# 1  Amazon Customer  Interesting book with a time travel theme alth...
#
#                          summary  unixReviewTime  \
# 0  Great book for military buffs      1494115200
# 1          A real Technothriller      1499817600
#
#                             style  ... imageURL imageURLHighRes details  \
# 0  {'Format:': ' Kindle Edition'}  ...       []              []     NaN
# 1  {'Format:': ' Kindle Edition'}  ...       []              []     NaN
#
#             categoryLast asin_right buy_frequency user_id_idx item_id_idx  \
# 0   Thrillers & Suspense         11             1      161512      195864
# 1   Thrillers & Suspense         11             1      161512      204576
#
#   price_right price_category
# 0        13.5              0
# 1        13.5              0
#
# [2 rows x 37 columns]

# %%
# Step 5: Generate the Top k neighbors 
h = np.array(h)
k = 5 # of similar users >>>>>  CHANGE THIS <<<<<<<<<<<<
distances = np.linalg.norm(h - h[index], axis = 1)
# select indices of vectors having the lowest distances from the X
neighbours = np.argpartition(distances, range(0, k))[:k]
node_names = [nodes_list[i] for i in neighbours]
print(f'Top {k} neighbours of {reviwerID_val} :{node_names}')
# Out:
# Top 5 neighbours of A1PZU88ONVYUHB :['A1PZU88ONVYUHB', 'A85FMKX6NA9R5', 'ADIGLF13KB5B5', 'A2I4KH6YJAAOUN', 'AHPV36THBG3SY']

# %%
# Step 6 : Table with all similar users and their books 
similar_users_df = data_df_3_sample.loc[data_df_3_sample['reviewerID'].isin(node_names)] # all books are 4 or 5 ratings
#print(similar_users_df['asin'])

# %%
# Asin are the suggestions and CategoryLast is its book category
# A2TS60D6XB4KBY is my reviewer and other are closest users
# A2TS60D6XB4KBY bought books on Women's Fiction, Contemprory, Paranormal
# We find lot of suggestion in same category from other users
recommendation = similar_users_df.groupby(['reviewerID','asin','categoryLast'])['overall'].count().reset_index(drop=False)

# %%
recommendation #<<< check the complete table
# Out:
#         reviewerID        asin                categoryLast  overall
# 0   A1PZU88ONVYUHB  0983797803               Genre Fiction        1
# 1   A1PZU88ONVYUHB  1442389982   Politics &amp; Government        1
# 2   A1PZU88ONVYUHB  1505414520               Genre Fiction        1
# 3   A1PZU88ONVYUHB  1505537908             Science Fiction        1
# 4   A1PZU88ONVYUHB  1507814046             Science Fiction        1
# 5   A1PZU88ONVYUHB  1512223018             Science Fiction        1
# 6   A1PZU88ONVYUHB  1530753228                     Mystery        1
# 7   A1PZU88ONVYUHB  1539951464                     Mystery        1
# 8   A1PZU88ONVYUHB  1542651999                     Mystery        1
# 9   A1PZU88ONVYUHB  1935070126    Thrillers &amp; Suspense        1
# 10  A1PZU88ONVYUHB  1939217105             Science Fiction        1
# 11  A2I4KH6YJAAOUN  0316558206             Science Fiction        1
# 12  A2I4KH6YJAAOUN  0988898098             Science Fiction        1
# 13  A2I4KH6YJAAOUN  0990522237             Science Fiction        1
# 14  A2I4KH6YJAAOUN  1520479980          Humor &amp; Satire        1
# 15  A2I4KH6YJAAOUN  1533127042    Literature &amp; Fiction        1
# 16  A2I4KH6YJAAOUN  1546789146             Science Fiction        1
# 17   A85FMKX6NA9R5  0736956573    Literature &amp; Fiction        1
# 18   A85FMKX6NA9R5  0764212494        Literature & Fiction        1
# 19   A85FMKX6NA9R5  0764214373    Literature &amp; Fiction        1
# 20   A85FMKX6NA9R5  0764216600    Literature &amp; Fiction        1
# 21   A85FMKX6NA9R5  0764218158    Literature &amp; Fiction        1
# 22   A85FMKX6NA9R5  0764218697            Christian Living        1
# 23   A85FMKX6NA9R5  080107536X            Christian Living        1
# 24   A85FMKX6NA9R5  1414379358    Literature &amp; Fiction        1
# 25   A85FMKX6NA9R5  1607747634         Biological Sciences        1
# 26   A85FMKX6NA9R5  1615644598        Crafts &amp; Hobbies        1
# 27   ADIGLF13KB5B5  0007178255              Graphic Design        1
# 28   ADIGLF13KB5B5  0008118922                                    1
# 29   ADIGLF13KB5B5  0062388657               United States        1
# 30   ADIGLF13KB5B5  1250066115     Diets &amp; Weight Loss        1
# 31   AHPV36THBG3SY  098991190X             Science Fiction        1
# 32   AHPV36THBG3SY  1484015800             Science Fiction        1
# 33   AHPV36THBG3SY  1491087366             Science Fiction        1
# 34   AHPV36THBG3SY  1519189397             Science Fiction        1
